# %%
# Import the requests library.
import requests
import pandas as pd
import json

# Import the API key.
from config import Yelp_API_Key

# %%
# Define the API key, Endpoint, and Header
API_KEY = Yelp_API_Key
ENDPOINT = 'https://api.yelp.com/v3/businesses/search'
HEADERS = {'Authorization':'bearer %s' % API_KEY}

# Define the parameters of the query
PARAMETERS = {'term': 'fast food',
            'limit': 50,
              'radius': 8000,
              'location': '77096',
             'offset': 50}

# Make a request to the Yelp API
response = requests.get(url = ENDPOINT, params = PARAMETERS, headers = HEADERS)

# convert JSON string to a dictionary
business_data = response.json()

print(business_data)
# Out:
# {'businesses': [{'id': '-Y5gYbTA-9LKOKysyk8-ng', 'alias': 'whataburger-houston-46', 'name': 'Whataburger', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NAw9rNb4Tm_F8xFtTJUgIw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/whataburger-houston-46?adjust_creative=XzK19ZTiN3mgGdqg5oa27w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=XzK19ZTiN3mgGdqg5oa27w', 'review_count': 26, 'categories': [{'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'hotdogs', 'title': 'Fast Food'}], 'rating': 2.0, 'coordinates': {'latitude': 29.655632640061892, 'longitude': -95.510533}, 'transactions': ['delivery'], 'price': '$', 'location': {'address1': '7629 W Bellfort St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77071', 'country': 'US', 'state': 'TX', 'display_address': ['7629 W Bellfort St', 'Houston, TX 77071']}, 'phone': '+17137298025', 'display_phone': '(713) 729-8025', 'distance': 3681.543495724447}, {'id': 'Wjq4pR7qHaoPu4d67v_qlw', 'alias': 'clutch-city-cluckers-houston', 'name': 'Clutch City Cluckers', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3B58fX-BqwTosXvjdHAgZQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/clutch-city-cluckers-houston?adjust_creative=XzK19ZTiN3mgGdqg5oa27w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=XzK19ZTiN3mgGdqg5oa27w', 'review_count': 105, 'categories': [{'alias': 'chickenshop', 'title': 'Chicken Shop'}, {'alias': 'foodtrucks', 'title': 'Food Trucks'}], 'rating': 4.0, 'coordinates': {'latitude': 29.73683, 'longitude': -95.47636}, 'transactions': ['pickup', 'delivery'], 'price': '$$', 'location': {'address1': '5550 Val Verde St', 'address2': None, 'address3': '', 'city': 'Houston', 'zip_code': '77056', 'country': 'US', 'state': 'TX', 'display_address': ['5550 Val Verde St', 'Houston, TX 77056']}, 'phone': '+12817665656', 'display_phone': '(281) 766-5656', 'distance': 7047.975784400008}, {'id': 'xN2Dr4KDlUJ3T1HDpiBlwg', 'alias': 'jimmy-johns-bellaire', 'name': "Jimmy John's", 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LJsION0FyjL2zkl_DLJHPA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/jimmy-johns-bellaire?adjust_creative=XzK19ZTiN3mgGdqg5oa27w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=XzK19ZTiN3mgGdqg5oa27w', 'review_count': 37, 'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'delis', 'title': 'Delis'}, {'alias': 'hotdogs', 'title': 'Fast Food'}], 'rating': 2.0, 'coordinates': {'latitude': 29.7067379, 'longitude': -95.4700107}, 'transactions': [], 'price': '$', 'location': {'address1': '5124 Bissonnet St', 'address2': '', 'address3': '', 'city': 'Bellaire', 'zip_code': '77401', 'country': 'US', 'state': 'TX', 'display_address': ['5124 Bissonnet St', 'Bellaire, TX 77401']}, 'phone': '+17136620056', 'display_phone': '(713) 662-0056', 'distance': 3791.618573746196}, {'id': 'cZMcMPW0HUO7SxHznBFS5Q', 'alias': 'smashburger-houston-26', 'name': 'Smashburger', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JKAEqa1nxSipbZtn9WJWuQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/smashburger-houston-26?adjust_creative=XzK19ZTiN3mgGdqg5oa27w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=XzK19ZTiN3mgGdqg5oa27w', 'review_count': 341, 'categories': [{'alias': 'burgers', 'title': 'Burgers'}], 'rating': 3.5, 'coordinates': {'latitude': 29.694638, 'longitude': -95.413638}, 'transactions': ['pickup', 'delivery'], 'price': '$', 'location': {'address1': '7811 Main St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['7811 Main St', 'Houston, TX 77030']}, 'phone': '+17134914526', 'display_phone': '(713) 491-4526', 'distance': 6686.099027149417}, {'id': '8LI2YiKvakSaRpgJRaGy1w', 'alias': 'popeyes-louisiana-kitchen-houston-40', 'name': 'Popeyes Louisiana Kitchen', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/iQzY6gbU7 ...

# %%
def yelp_biz_function(zip):
    # Define the API key, Endpoint, and Header
    API_KEY = Yelp_API_Key
    ENDPOINT = 'https://api.yelp.com/v3/businesses/search'
    HEADERS = {'Authorization':'bearer %s' % API_KEY}

    # Define the parameters of the query
    PARAMETERS = {'term': 'fast food',
                  'limit': 50,
                  'radius': 8000,
                  'location': zip,
                  'offset': 50}

    # Make a request to the Yelp API
    response = requests.get(url = ENDPOINT, params = PARAMETERS, headers = HEADERS)

    # convert JSON string to a dictionary
    business_data = response.json()
    
    for biz in business_data['businesses']:
        print(biz['name'],biz['location'])

# %%
def get_restaurants():
    for i in range(5):
        yelp_biz_function('77051')

# %%
get_restaurants()
# Out:
# Taco Bell {'address1': '3155 S Loop West', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77054', 'country': 'US', 'state': 'TX', 'display_address': ['3155 S Loop West', 'Houston, TX 77054']}
# American Deli {'address1': '6102 Scott St', 'address2': None, 'address3': '', 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['6102 Scott St', 'Houston, TX 77021']}
# KFC {'address1': '9227 Cullen Blvd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77051', 'country': 'US', 'state': 'TX', 'display_address': ['9227 Cullen Blvd', 'Houston, TX 77051']}
# Miller's Cafe {'address1': '6560 Fannin St', 'address2': 'Ste 110', 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['6560 Fannin St', 'Ste 110', 'Houston, TX 77030']}
# Taco Cabana {'address1': '8101 S Main St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77025', 'country': 'US', 'state': 'TX', 'display_address': ['8101 S Main St', 'Houston, TX 77025']}
# Chick-fil-A {'address1': '6550 Bertner Ave', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['6550 Bertner Ave', 'Houston, TX 77030']}
# Maxim Seafood {'address1': '6510 Weston St', 'address2': None, 'address3': '', 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['6510 Weston St', 'Houston, TX 77021']}
# Subway {'address1': '9025 Cullen Blvd', 'address2': 'Ste 100', 'address3': '', 'city': 'Houston', 'zip_code': '77051', 'country': 'US', 'state': 'TX', 'display_address': ['9025 Cullen Blvd', 'Ste 100', 'Houston, TX 77051']}
# Chick-fil-A {'address1': '1515 Holcombe Blvd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['1515 Holcombe Blvd', 'Houston, TX 77030']}
# McDonald's {'address1': '6621 Fannin St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['6621 Fannin St', 'Houston, TX 77030']}
# Jack in the Box {'address1': '8767 S Main St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77025', 'country': 'US', 'state': 'TX', 'display_address': ['8767 S Main St', 'Houston, TX 77025']}
# Wing Quarter {'address1': '3929 Old Spanish Trl', 'address2': 'Ste 100', 'address3': None, 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['3929 Old Spanish Trl', 'Ste 100', 'Houston, TX 77021']}
# Chick-fil-A {'address1': '3801 Cullen Blvd', 'address2': None, 'address3': None, 'city': 'Houston', 'zip_code': '77004', 'country': 'US', 'state': 'TX', 'display_address': ['3801 Cullen Blvd', 'Houston, TX 77004']}
# Taco Bell {'address1': '2245 West Holcombe Blvd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['2245 West Holcombe Blvd', 'Houston, TX 77030']}
# Whataburger {'address1': '3624 Old Spanish Trl', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['3624 Old Spanish Trl', 'Houston, TX 77021']}
# Ms Betty's Kitchen {'address1': '4101 Reed Rd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77051', 'country': 'US', 'state': 'TX', 'display_address': ['4101 Reed Rd', 'Houston, TX 77051']}
# Popeyes Louisiana Kitchen {'address1': '9120 Main St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77025', 'country': 'US', 'state': 'TX', 'display_address': ['9120 Main St', 'Houston, TX 77025']}
# Local Foods {'address1': '2424 Dunstan Rd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77005', 'country': 'US', 'state': 'TX', 'display_address': ['2424 Dunstan Rd', 'Houston, TX 77005']}
# Chick-fil-A {'address1': '3101 W Holcombe Blvd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77025', 'country': 'US', 'state': 'TX', 'display_address': ['3101 W Holcombe Blvd', 'Houston, TX 77025']}
# Sonic Drive-In {'address1': '8504 Main St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77025', 'country': 'US', 'state': 'TX', 'display_address': ['8504 Main St', 'Houston, TX 77025']}
# Frenchy's Chicken {'address1': '12202 Almeda Rd', 'address2': 'Ste B', 'address3': '', 'city': 'Houston', 'zip_code': '77045', 'country': 'US', 'state': 'TX', 'display_address': ['12202 Almeda Rd', 'Ste B', 'Houston, TX 77045']}
# Frenchy's Chicken {'address1': '4646 Scott St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77004', 'country': 'US', 'state': 'TX', 'display_address': ['4646 Scott St', 'Houston, TX 77004']}
# Burger King {'address1': '9349 S Main', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77025', 'country': 'US', 'state': 'TX', 'display_address': ['9349 S Main', 'Houston, TX 77025']}
# Panda Express {'address1': '4041 S. Sam Houston Pkwy E.', 'address2': None, 'address3': None, 'city': 'Houston', 'zip_code': '77047', 'country': 'US', 'state': 'TX', 'display_address': ['4041 S. Sam Houston Pkwy E.', 'Houston, TX 77047']}
# Whataburger {'address1': '2265 W Holcombe Blvd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['2265 W Holcombe Blvd', 'Houston, TX 77030']}
# Hopdoddy Burger Bar {'address1': '5510 Morningside Dr', 'address2': 'Ste 100', 'address3': None, 'city': 'Houston', 'zip_code': '77005', 'country': 'US', 'state': 'TX', 'display_address': ['5510 Morningside Dr', 'Ste 100', 'Houston, TX 77005']}
# Los Cocos Restaurant {'address1': '3419 W Orem Dr', 'address2': None, 'address3': '', 'city': 'Houston', 'zip_code': '77045', 'country': 'US', 'state': 'TX', 'display_address': ['3419 W Orem Dr', 'Houston, TX 77045']}
# Liberty Taco {'address1': '1333 Old Spanish Trl', 'address2': 'Ste 100-A', 'address3': None, 'city': 'Houston', 'zip_code': '77054', 'country': 'US', 'state': 'TX', 'display_address': ['1333 Old Spanish Trl', 'Ste 100-A', 'Houston, TX 77054']}
# Jack in the Box {'address1': '3601 Old Spanish Trail', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['3601 Old Spanish Trail', 'Houston, TX 77021']}
# Little Matt's {'address1': '6203 Edloe St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77005', 'country': 'US', 'state': 'TX', 'display_address': ['6203 Edloe St', 'Houston, TX 77005']}
# Fajita Pete's - Bellaire {'address1': '6719 Weslayan St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77005', 'country': 'US', 'state': 'TX', 'display_address': ['6719 Weslayan St', 'Houston, TX 77005']}
# McDonald's {'address1': '7410 Cullen Blvd', 'address2': None, 'address3': None, 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['7410 Cullen Blvd', 'Houston, TX 77021']}
# Taco Cabana {'address1': '5930 Gulf Frwy', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77023', 'country': 'US', 'state': 'TX', 'display_address': ['5930 Gulf Frwy', 'Houston, TX 77023']}
# Dairy Queen {'address1': '3915 Old Spanish Trail', 'address2': '', 'address3': None, 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['3915 Old Spanish Trail', 'Houston, TX 77021']}
# Golden Chick {'address1': '7121 Cullen Blvd', 'address2': None, 'address3': None, 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['7121 Cullen Blvd', 'Houston, TX 77021']}
# Popeyes Louisiana Kitchen {'address1': '4702 Scott St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77004', 'country': 'US', 'state': 'TX', 'display_address': ['4702 Scott St', 'Houston, TX 77004']}
# The Address {'address1': '3333 Raleigh St', 'address2': '', 'address3': None, 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['3333 Raleigh St', 'Houston, TX 77021']}
# Brown Bag Deli {'address1': '2540 Amherst St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77005', 'country': 'US', 'state': 'TX', 'display_address': ['2540 Amherst St', 'Houston, TX 77005']}
# Jimmy John's {'address1': '2401 W Holcombe Blvd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['2401 W Holcombe Blvd', 'Houston, TX 77030']}
# Pizza Hut {'address1': '9441 Cullen Blvd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77033', 'country': 'US', 'state': 'TX', 'display_address': ['9441 Cullen Blvd', 'Houston, TX 77033']}
# Burger King {'address1': '2116 W Holcombe Blvd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['2116 W Holcombe Blvd', 'Houston, TX 77030']}
# Fuddruckers {'address1': '2400 B S MacGregor Way', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['2400 B S MacGregor Way', 'Houston, TX 77021']}
# Taco Bell {'address1': '3720 Old Spanish Trail', 'address2': None, 'address3': None, 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['3720 Old Spanish Trail', 'Houston, TX 77021']}
# Sonic Drive-In {'address1': '13280 Almeda Rd', 'address2': None, 'address3': None, 'city': 'Houston', 'zip_code': '77045', 'country': 'US', 'state': 'TX', 'display_address': ['13280 Almeda Rd', 'Houston, TX 77045']}
# Church's Chicken {'address1': '13350 Almeda Rd', 'address2': '', 'address3': None, 'city': 'Houston', 'zip_code': '77045', 'country': 'US', 'state': 'TX', 'display_address': ['13350 Almeda Rd', 'Houston, TX 77045']}
# Jack in the Box {'address1': '4400 W Fuqua St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77045', 'country': 'US', 'state': 'TX', 'display_address': ['4400 W Fuqua St', 'Houston, TX 77045']}
# KFC {'address1': '4044 W Fuqua St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77045', 'country': 'US', 'state': 'TX', 'display_address': ['4044 W Fuqua St', 'Houston, TX 77045']}
# Poke In The Bowl {'address1': '6611 Main St', 'address2': None, 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['6611 Main St', 'Houston, TX 77030']}
# Pokeworks {'address1': '8505 Main St', 'address2': 'Ste 150', 'address3': None, 'city': 'Houston', 'zip_code': '77025', 'country': 'US', 'state': 'TX', 'display_address': ['8505 Main St', 'Ste 150', 'Houston, TX 77025']}
# Louisiana Famous Fried Chicken {'address1': '3602 Old Spanish Trl', 'address2': 'Ste C', 'address3': '', 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['3602 Old Spanish Trl', 'Ste C', 'Houston, TX 77021']}
# Taco Bell {'address1': '3155 S Loop West', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77054', 'country': 'US', 'state': 'TX', 'display_address': ['3155 S Loop West', 'Houston, TX 77054']}
# American Deli {'address1': '6102 Scott St', 'address2': None, 'address3': '', 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['6102 Scott St', 'Houston, TX 77021']}
# KFC {'address1': '9227 Cullen Blvd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77051', 'country': 'US', 'state': 'TX', 'display_address': ['9227 Cullen Blvd', 'Houston, TX 77051']}
# Miller's Cafe {'address1': '6560 Fannin St', 'address2': 'Ste 110', 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['6560 Fannin St', 'Ste 110', 'Houston, TX 77030']}
# Taco Cabana {'address1': '8101 S Main St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77025', 'country': 'US', 'state': 'TX', 'display_address': ['8101 S Main St', 'Houston, TX 77025']}
# Chick-fil-A {'address1': '6550 Bertner Ave', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['6550 Bertner Ave', 'Houston, TX 77030']}
# Maxim Seafood {'address1': '6510 Weston St', 'address2': None, 'address3': '', 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['6510 Weston St', 'Houston, TX 77021']}
# Subway {'address1': '9025 Cullen Blvd', 'address2': 'Ste 100', 'address3': '', 'city': 'Houston', 'zip_code': '77051', 'country': 'US', 'state': 'TX', 'display_address': ['9025 Cullen Blvd', 'Ste 100', 'Houston, TX 77051']}
# Chick-fil-A {'address1': '1515 Holcombe Blvd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['1515 Holcombe Blvd', 'Houston, TX 77030']}
# McDonald's {'address1': '6621 Fannin St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['6621 Fannin St', 'Houston, TX 77030']}
# Jack in the Box {'address1': '8767 S Main St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77025', 'country': 'US', 'state': 'TX', 'display_address': ['8767 S Main St', 'Houston, TX 77025']}
# Wing Quarter {'address1': '3929 Old Spanish Trl', 'address2': 'Ste 100', 'address3': None, 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['3929 Old Spanish Trl', 'Ste 100', 'Houston, TX 77021']}
# Chick-fil-A {'address1': '3801 Cullen Blvd', 'address2': None, 'address3': None, 'city': 'Houston', 'zip_code': '77004', 'country': 'US', 'state': 'TX', 'display_address': ['3801 Cullen Blvd', 'Houston, TX 77004']}
# Taco Bell {'address1': '2245 West Holcombe Blvd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['2245 West Holcombe Blvd', 'Houston, TX 77030']}
# Whataburger {'address1': '3624 Old Spanish Trl', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['3624 Old Spanish Trl', 'Houston, TX 77021']}
# Ms Betty's Kitchen {'address1': '4101 Reed Rd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77051', 'country': 'US', 'state': 'TX', 'display_address': ['4101 Reed Rd', 'Houston, TX 77051']}
# Popeyes Louisiana Kitchen {'address1': '9120 Main St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77025', 'country': 'US', 'state': 'TX', 'display_address': ['9120 Main St', 'Houston, TX 77025']}
# Local Foods {'address1': '2424 Dunstan Rd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77005', 'country': 'US', 'state': 'TX', 'display_address': ['2424 Dunstan Rd', 'Houston, TX 77005']}
# Chick-fil-A {'address1': '3101 W Holcombe Blvd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77025', 'country': 'US', 'state': 'TX', 'display_address': ['3101 W Holcombe Blvd', 'Houston, TX 77025']}
# Sonic Drive-In {'address1': '8504 Main St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77025', 'country': 'US', 'state': 'TX', 'display_address': ['8504 Main St', 'Houston, TX 77025']}
# Frenchy's Chicken {'address1': '12202 Almeda Rd', 'address2': 'Ste B', 'address3': '', 'city': 'Houston', 'zip_code': '77045', 'country': 'US', 'state': 'TX', 'display_address': ['12202 Almeda Rd', 'Ste B', 'Houston, TX 77045']}
# Frenchy's Chicken {'address1': '4646 Scott St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77004', 'country': 'US', 'state': 'TX', 'display_address': ['4646 Scott St', 'Houston, TX 77004']}
# Burger King {'address1': '9349 S Main', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77025', 'country': 'US', 'state': 'TX', 'display_address': ['9349 S Main', 'Houston, TX 77025']}
# Panda Express {'address1': '4041 S. Sam Houston Pkwy E.', 'address2': None, 'address3': None, 'city': 'Houston', 'zip_code': '77047', 'country': 'US', 'state': 'TX', 'display_address': ['4041 S. Sam Houston Pkwy E.', 'Houston, TX 77047']}
# Whataburger {'address1': '2265 W Holcombe Blvd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['2265 W Holcombe Blvd', 'Houston, TX 77030']}
# Hopdoddy Burger Bar {'address1': '5510 Morningside Dr', 'address2': 'Ste 100', 'address3': None, 'city': 'Houston', 'zip_code': '77005', 'country': 'US', 'state': 'TX', 'display_address': ['5510 Morningside Dr', 'Ste 100', 'Houston, TX 77005']}
# Los Cocos Restaurant {'address1': '3419 W Orem Dr', 'address2': None, 'address3': '', 'city': 'Houston', 'zip_code': '77045', 'country': 'US', 'state': 'TX', 'display_address': ['3419 W Orem Dr', 'Houston, TX 77045']}
# Liberty Taco {'address1': '1333 Old Spanish Trl', 'address2': 'Ste 100-A', 'address3': None, 'city': 'Houston', 'zip_code': '77054', 'country': 'US', 'state': 'TX', 'display_address': ['1333 Old Spanish Trl', 'Ste 100-A', 'Houston, TX 77054']}
# Jack in the Box {'address1': '3601 Old Spanish Trail', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['3601 Old Spanish Trail', 'Houston, TX 77021']}
# Little Matt's {'address1': '6203 Edloe St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77005', 'country': 'US', 'state': 'TX', 'display_address': ['6203 Edloe St', 'Houston, TX 77005']}
# Fajita Pete's - Bellaire {'address1': '6719 Weslayan St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77005', 'country': 'US', 'state': 'TX', 'display_address': ['6719 Weslayan St', 'Houston, TX 77005']}
# McDonald's {'address1': '7410 Cullen Blvd', 'address2': None, 'address3': None, 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['7410 Cullen Blvd', 'Houston, TX 77021']}
# Taco Cabana {'address1': '5930 Gulf Frwy', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77023', 'country': 'US', 'state': 'TX', 'display_address': ['5930 Gulf Frwy', 'Houston, TX 77023']}
# Dairy Queen {'address1': '3915 Old Spanish Trail', 'address2': '', 'address3': None, 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['3915 Old Spanish Trail', 'Houston, TX 77021']}
# Golden Chick {'address1': '7121 Cullen Blvd', 'address2': None, 'address3': None, 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['7121 Cullen Blvd', 'Houston, TX 77021']}
# Popeyes Louisiana Kitchen {'address1': '4702 Scott St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77004', 'country': 'US', 'state': 'TX', 'display_address': ['4702 Scott St', 'Houston, TX 77004']}
# The Address {'address1': '3333 Raleigh St', 'address2': '', 'address3': None, 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['3333 Raleigh St', 'Houston, TX 77021']}
# Brown Bag Deli {'address1': '2540 Amherst St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77005', 'country': 'US', 'state': 'TX', 'display_address': ['2540 Amherst St', 'Houston, TX 77005']}
# Jimmy John's {'address1': '2401 W Holcombe Blvd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['2401 W Holcombe Blvd', 'Houston, TX 77030']}
# Pizza Hut {'address1': '9441 Cullen Blvd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77033', 'country': 'US', 'state': 'TX', 'display_address': ['9441 Cullen Blvd', 'Houston, TX 77033']}
# Burger King {'address1': '2116 W Holcombe Blvd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['2116 W Holcombe Blvd', 'Houston, TX 77030']}
# Fuddruckers {'address1': '2400 B S MacGregor Way', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['2400 B S MacGregor Way', 'Houston, TX 77021']}
# Taco Bell {'address1': '3720 Old Spanish Trail', 'address2': None, 'address3': None, 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['3720 Old Spanish Trail', 'Houston, TX 77021']}
# Sonic Drive-In {'address1': '13280 Almeda Rd', 'address2': None, 'address3': None, 'city': 'Houston', 'zip_code': '77045', 'country': 'US', 'state': 'TX', 'display_address': ['13280 Almeda Rd', 'Houston, TX 77045']}
# Church's Chicken {'address1': '13350 Almeda Rd', 'address2': '', 'address3': None, 'city': 'Houston', 'zip_code': '77045', 'country': 'US', 'state': 'TX', 'display_address': ['13350 Almeda Rd', 'Houston, TX 77045']}
# Jack in the Box {'address1': '4400 W Fuqua St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77045', 'country': 'US', 'state': 'TX', 'display_address': ['4400 W Fuqua St', 'Houston, TX 77045']}
# KFC {'address1': '4044 W Fuqua St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77045', 'country': 'US', 'state': 'TX', 'display_address': ['4044 W Fuqua St', 'Houston, TX 77045']}
# Poke In The Bowl {'address1': '6611 Main St', 'address2': None, 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['6611 Main St', 'Houston, TX 77030']}
# Pokeworks {'address1': '8505 Main St', 'address2': 'Ste 150', 'address3': None, 'city': 'Houston', 'zip_code': '77025', 'country': 'US', 'state': 'TX', 'display_address': ['8505 Main St', 'Ste 150', 'Houston, TX 77025']}
# Louisiana Famous Fried Chicken {'address1': '3602 Old Spanish Trl', 'address2': 'Ste C', 'address3': '', 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['3602 Old Spanish Trl', 'Ste C', 'Houston, TX 77021']}
# Taco Bell {'address1': '3155 S Loop West', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77054', 'country': 'US', 'state': 'TX', 'display_address': ['3155 S Loop West', 'Houston, TX 77054']}
# American Deli {'address1': '6102 Scott St', 'address2': None, 'address3': '', 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['6102 Scott St', 'Houston, TX 77021']}
# KFC {'address1': '9227 Cullen Blvd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77051', 'country': 'US', 'state': 'TX', 'display_address': ['9227 Cullen Blvd', 'Houston, TX 77051']}
# Miller's Cafe {'address1': '6560 Fannin St', 'address2': 'Ste 110', 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['6560 Fannin St', 'Ste 110', 'Houston, TX 77030']}
# Taco Cabana {'address1': '8101 S Main St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77025', 'country': 'US', 'state': 'TX', 'display_address': ['8101 S Main St', 'Houston, TX 77025']}
# Chick-fil-A {'address1': '6550 Bertner Ave', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['6550 Bertner Ave', 'Houston, TX 77030']}
# Maxim Seafood {'address1': '6510 Weston St', 'address2': None, 'address3': '', 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['6510 Weston St', 'Houston, TX 77021']}
# Subway {'address1': '9025 Cullen Blvd', 'address2': 'Ste 100', 'address3': '', 'city': 'Houston', 'zip_code': '77051', 'country': 'US', 'state': 'TX', 'display_address': ['9025 Cullen Blvd', 'Ste 100', 'Houston, TX 77051']}
# Chick-fil-A {'address1': '1515 Holcombe Blvd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['1515 Holcombe Blvd', 'Houston, TX 77030']}
# McDonald's {'address1': '6621 Fannin St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['6621 Fannin St', 'Houston, TX 77030']}
# Jack in the Box {'address1': '8767 S Main St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77025', 'country': 'US', 'state': 'TX', 'display_address': ['8767 S Main St', 'Houston, TX 77025']}
# Wing Quarter {'address1': '3929 Old Spanish Trl', 'address2': 'Ste 100', 'address3': None, 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['3929 Old Spanish Trl', 'Ste 100', 'Houston, TX 77021']}
# Chick-fil-A {'address1': '3801 Cullen Blvd', 'address2': None, 'address3': None, 'city': 'Houston', 'zip_code': '77004', 'country': 'US', 'state': 'TX', 'display_address': ['3801 Cullen Blvd', 'Houston, TX 77004']}
# Taco Bell {'address1': '2245 West Holcombe Blvd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['2245 West Holcombe Blvd', 'Houston, TX 77030']}
# Whataburger {'address1': '3624 Old Spanish Trl', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['3624 Old Spanish Trl', 'Houston, TX 77021']}
# Ms Betty's Kitchen {'address1': '4101 Reed Rd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77051', 'country': 'US', 'state': 'TX', 'display_address': ['4101 Reed Rd', 'Houston, TX 77051']}
# Popeyes Louisiana Kitchen {'address1': '9120 Main St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77025', 'country': 'US', 'state': 'TX', 'display_address': ['9120 Main St', 'Houston, TX 77025']}
# Local Foods {'address1': '2424 Dunstan Rd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77005', 'country': 'US', 'state': 'TX', 'display_address': ['2424 Dunstan Rd', 'Houston, TX 77005']}
# Chick-fil-A {'address1': '3101 W Holcombe Blvd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77025', 'country': 'US', 'state': 'TX', 'display_address': ['3101 W Holcombe Blvd', 'Houston, TX 77025']}
# Sonic Drive-In {'address1': '8504 Main St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77025', 'country': 'US', 'state': 'TX', 'display_address': ['8504 Main St', 'Houston, TX 77025']}
# Frenchy's Chicken {'address1': '12202 Almeda Rd', 'address2': 'Ste B', 'address3': '', 'city': 'Houston', 'zip_code': '77045', 'country': 'US', 'state': 'TX', 'display_address': ['12202 Almeda Rd', 'Ste B', 'Houston, TX 77045']}
# Frenchy's Chicken {'address1': '4646 Scott St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77004', 'country': 'US', 'state': 'TX', 'display_address': ['4646 Scott St', 'Houston, TX 77004']}
# Burger King {'address1': '9349 S Main', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77025', 'country': 'US', 'state': 'TX', 'display_address': ['9349 S Main', 'Houston, TX 77025']}
# Panda Express {'address1': '4041 S. Sam Houston Pkwy E.', 'address2': None, 'address3': None, 'city': 'Houston', 'zip_code': '77047', 'country': 'US', 'state': 'TX', 'display_address': ['4041 S. Sam Houston Pkwy E.', 'Houston, TX 77047']}
# Whataburger {'address1': '2265 W Holcombe Blvd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['2265 W Holcombe Blvd', 'Houston, TX 77030']}
# Hopdoddy Burger Bar {'address1': '5510 Morningside Dr', 'address2': 'Ste 100', 'address3': None, 'city': 'Houston', 'zip_code': '77005', 'country': 'US', 'state': 'TX', 'display_address': ['5510 Morningside Dr', 'Ste 100', 'Houston, TX 77005']}
# Los Cocos Restaurant {'address1': '3419 W Orem Dr', 'address2': None, 'address3': '', 'city': 'Houston', 'zip_code': '77045', 'country': 'US', 'state': 'TX', 'display_address': ['3419 W Orem Dr', 'Houston, TX 77045']}
# Liberty Taco {'address1': '1333 Old Spanish Trl', 'address2': 'Ste 100-A', 'address3': None, 'city': 'Houston', 'zip_code': '77054', 'country': 'US', 'state': 'TX', 'display_address': ['1333 Old Spanish Trl', 'Ste 100-A', 'Houston, TX 77054']}
# Jack in the Box {'address1': '3601 Old Spanish Trail', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['3601 Old Spanish Trail', 'Houston, TX 77021']}
# Little Matt's {'address1': '6203 Edloe St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77005', 'country': 'US', 'state': 'TX', 'display_address': ['6203 Edloe St', 'Houston, TX 77005']}
# Fajita Pete's - Bellaire {'address1': '6719 Weslayan St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77005', 'country': 'US', 'state': 'TX', 'display_address': ['6719 Weslayan St', 'Houston, TX 77005']}
# McDonald's {'address1': '7410 Cullen Blvd', 'address2': None, 'address3': None, 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['7410 Cullen Blvd', 'Houston, TX 77021']}
# Taco Cabana {'address1': '5930 Gulf Frwy', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77023', 'country': 'US', 'state': 'TX', 'display_address': ['5930 Gulf Frwy', 'Houston, TX 77023']}
# Dairy Queen {'address1': '3915 Old Spanish Trail', 'address2': '', 'address3': None, 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['3915 Old Spanish Trail', 'Houston, TX 77021']}
# Golden Chick {'address1': '7121 Cullen Blvd', 'address2': None, 'address3': None, 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['7121 Cullen Blvd', 'Houston, TX 77021']}
# Popeyes Louisiana Kitchen {'address1': '4702 Scott St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77004', 'country': 'US', 'state': 'TX', 'display_address': ['4702 Scott St', 'Houston, TX 77004']}
# The Address {'address1': '3333 Raleigh St', 'address2': '', 'address3': None, 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['3333 Raleigh St', 'Houston, TX 77021']}
# Brown Bag Deli {'address1': '2540 Amherst St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77005', 'country': 'US', 'state': 'TX', 'display_address': ['2540 Amherst St', 'Houston, TX 77005']}
# Jimmy John's {'address1': '2401 W Holcombe Blvd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['2401 W Holcombe Blvd', 'Houston, TX 77030']}
# Pizza Hut {'address1': '9441 Cullen Blvd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77033', 'country': 'US', 'state': 'TX', 'display_address': ['9441 Cullen Blvd', 'Houston, TX 77033']}
# Burger King {'address1': '2116 W Holcombe Blvd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['2116 W Holcombe Blvd', 'Houston, TX 77030']}
# Fuddruckers {'address1': '2400 B S MacGregor Way', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['2400 B S MacGregor Way', 'Houston, TX 77021']}
# Taco Bell {'address1': '3720 Old Spanish Trail', 'address2': None, 'address3': None, 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['3720 Old Spanish Trail', 'Houston, TX 77021']}
# Sonic Drive-In {'address1': '13280 Almeda Rd', 'address2': None, 'address3': None, 'city': 'Houston', 'zip_code': '77045', 'country': 'US', 'state': 'TX', 'display_address': ['13280 Almeda Rd', 'Houston, TX 77045']}
# Church's Chicken {'address1': '13350 Almeda Rd', 'address2': '', 'address3': None, 'city': 'Houston', 'zip_code': '77045', 'country': 'US', 'state': 'TX', 'display_address': ['13350 Almeda Rd', 'Houston, TX 77045']}
# Jack in the Box {'address1': '4400 W Fuqua St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77045', 'country': 'US', 'state': 'TX', 'display_address': ['4400 W Fuqua St', 'Houston, TX 77045']}
# KFC {'address1': '4044 W Fuqua St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77045', 'country': 'US', 'state': 'TX', 'display_address': ['4044 W Fuqua St', 'Houston, TX 77045']}
# Poke In The Bowl {'address1': '6611 Main St', 'address2': None, 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['6611 Main St', 'Houston, TX 77030']}
# Pokeworks {'address1': '8505 Main St', 'address2': 'Ste 150', 'address3': None, 'city': 'Houston', 'zip_code': '77025', 'country': 'US', 'state': 'TX', 'display_address': ['8505 Main St', 'Ste 150', 'Houston, TX 77025']}
# Louisiana Famous Fried Chicken {'address1': '3602 Old Spanish Trl', 'address2': 'Ste C', 'address3': '', 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['3602 Old Spanish Trl', 'Ste C', 'Houston, TX 77021']}
# Taco Bell {'address1': '3155 S Loop West', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77054', 'country': 'US', 'state': 'TX', 'display_address': ['3155 S Loop West', 'Houston, TX 77054']}
# American Deli {'address1': '6102 Scott St', 'address2': None, 'address3': '', 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['6102 Scott St', 'Houston, TX 77021']}
# KFC {'address1': '9227 Cullen Blvd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77051', 'country': 'US', 'state': 'TX', 'display_address': ['9227 Cullen Blvd', 'Houston, TX 77051']}
# Miller's Cafe {'address1': '6560 Fannin St', 'address2': 'Ste 110', 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['6560 Fannin St', 'Ste 110', 'Houston, TX 77030']}
# Taco Cabana {'address1': '8101 S Main St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77025', 'country': 'US', 'state': 'TX', 'display_address': ['8101 S Main St', 'Houston, TX 77025']}
# Chick-fil-A {'address1': '6550 Bertner Ave', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['6550 Bertner Ave', 'Houston, TX 77030']}
# Maxim Seafood {'address1': '6510 Weston St', 'address2': None, 'address3': '', 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['6510 Weston St', 'Houston, TX 77021']}
# Subway {'address1': '9025 Cullen Blvd', 'address2': 'Ste 100', 'address3': '', 'city': 'Houston', 'zip_code': '77051', 'country': 'US', 'state': 'TX', 'display_address': ['9025 Cullen Blvd', 'Ste 100', 'Houston, TX 77051']}
# Chick-fil-A {'address1': '1515 Holcombe Blvd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['1515 Holcombe Blvd', 'Houston, TX 77030']}
# McDonald's {'address1': '6621 Fannin St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['6621 Fannin St', 'Houston, TX 77030']}
# Jack in the Box {'address1': '8767 S Main St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77025', 'country': 'US', 'state': 'TX', 'display_address': ['8767 S Main St', 'Houston, TX 77025']}
# Wing Quarter {'address1': '3929 Old Spanish Trl', 'address2': 'Ste 100', 'address3': None, 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['3929 Old Spanish Trl', 'Ste 100', 'Houston, TX 77021']}
# Chick-fil-A {'address1': '3801 Cullen Blvd', 'address2': None, 'address3': None, 'city': 'Houston', 'zip_code': '77004', 'country': 'US', 'state': 'TX', 'display_address': ['3801 Cullen Blvd', 'Houston, TX 77004']}
# Taco Bell {'address1': '2245 West Holcombe Blvd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['2245 West Holcombe Blvd', 'Houston, TX 77030']}
# Whataburger {'address1': '3624 Old Spanish Trl', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['3624 Old Spanish Trl', 'Houston, TX 77021']}
# Ms Betty's Kitchen {'address1': '4101 Reed Rd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77051', 'country': 'US', 'state': 'TX', 'display_address': ['4101 Reed Rd', 'Houston, TX 77051']}
# Popeyes Louisiana Kitchen {'address1': '9120 Main St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77025', 'country': 'US', 'state': 'TX', 'display_address': ['9120 Main St', 'Houston, TX 77025']}
# Local Foods {'address1': '2424 Dunstan Rd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77005', 'country': 'US', 'state': 'TX', 'display_address': ['2424 Dunstan Rd', 'Houston, TX 77005']}
# Chick-fil-A {'address1': '3101 W Holcombe Blvd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77025', 'country': 'US', 'state': 'TX', 'display_address': ['3101 W Holcombe Blvd', 'Houston, TX 77025']}
# Sonic Drive-In {'address1': '8504 Main St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77025', 'country': 'US', 'state': 'TX', 'display_address': ['8504 Main St', 'Houston, TX 77025']}
# Frenchy's Chicken {'address1': '12202 Almeda Rd', 'address2': 'Ste B', 'address3': '', 'city': 'Houston', 'zip_code': '77045', 'country': 'US', 'state': 'TX', 'display_address': ['12202 Almeda Rd', 'Ste B', 'Houston, TX 77045']}
# Frenchy's Chicken {'address1': '4646 Scott St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77004', 'country': 'US', 'state': 'TX', 'display_address': ['4646 Scott St', 'Houston, TX 77004']}
# Burger King {'address1': '9349 S Main', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77025', 'country': 'US', 'state': 'TX', 'display_address': ['9349 S Main', 'Houston, TX 77025']}
# Panda Express {'address1': '4041 S. Sam Houston Pkwy E.', 'address2': None, 'address3': None, 'city': 'Houston', 'zip_code': '77047', 'country': 'US', 'state': 'TX', 'display_address': ['4041 S. Sam Houston Pkwy E.', 'Houston, TX 77047']}
# Whataburger {'address1': '2265 W Holcombe Blvd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['2265 W Holcombe Blvd', 'Houston, TX 77030']}
# Hopdoddy Burger Bar {'address1': '5510 Morningside Dr', 'address2': 'Ste 100', 'address3': None, 'city': 'Houston', 'zip_code': '77005', 'country': 'US', 'state': 'TX', 'display_address': ['5510 Morningside Dr', 'Ste 100', 'Houston, TX 77005']}
# Los Cocos Restaurant {'address1': '3419 W Orem Dr', 'address2': None, 'address3': '', 'city': 'Houston', 'zip_code': '77045', 'country': 'US', 'state': 'TX', 'display_address': ['3419 W Orem Dr', 'Houston, TX 77045']}
# Liberty Taco {'address1': '1333 Old Spanish Trl', 'address2': 'Ste 100-A', 'address3': None, 'city': 'Houston', 'zip_code': '77054', 'country': 'US', 'state': 'TX', 'display_address': ['1333 Old Spanish Trl', 'Ste 100-A', 'Houston, TX 77054']}
# Jack in the Box {'address1': '3601 Old Spanish Trail', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['3601 Old Spanish Trail', 'Houston, TX 77021']}
# Little Matt's {'address1': '6203 Edloe St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77005', 'country': 'US', 'state': 'TX', 'display_address': ['6203 Edloe St', 'Houston, TX 77005']}
# Fajita Pete's - Bellaire {'address1': '6719 Weslayan St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77005', 'country': 'US', 'state': 'TX', 'display_address': ['6719 Weslayan St', 'Houston, TX 77005']}
# McDonald's {'address1': '7410 Cullen Blvd', 'address2': None, 'address3': None, 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['7410 Cullen Blvd', 'Houston, TX 77021']}
# Taco Cabana {'address1': '5930 Gulf Frwy', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77023', 'country': 'US', 'state': 'TX', 'display_address': ['5930 Gulf Frwy', 'Houston, TX 77023']}
# Dairy Queen {'address1': '3915 Old Spanish Trail', 'address2': '', 'address3': None, 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['3915 Old Spanish Trail', 'Houston, TX 77021']}
# Golden Chick {'address1': '7121 Cullen Blvd', 'address2': None, 'address3': None, 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['7121 Cullen Blvd', 'Houston, TX 77021']}
# Popeyes Louisiana Kitchen {'address1': '4702 Scott St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77004', 'country': 'US', 'state': 'TX', 'display_address': ['4702 Scott St', 'Houston, TX 77004']}
# The Address {'address1': '3333 Raleigh St', 'address2': '', 'address3': None, 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['3333 Raleigh St', 'Houston, TX 77021']}
# Brown Bag Deli {'address1': '2540 Amherst St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77005', 'country': 'US', 'state': 'TX', 'display_address': ['2540 Amherst St', 'Houston, TX 77005']}
# Jimmy John's {'address1': '2401 W Holcombe Blvd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['2401 W Holcombe Blvd', 'Houston, TX 77030']}
# Pizza Hut {'address1': '9441 Cullen Blvd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77033', 'country': 'US', 'state': 'TX', 'display_address': ['9441 Cullen Blvd', 'Houston, TX 77033']}
# Burger King {'address1': '2116 W Holcombe Blvd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['2116 W Holcombe Blvd', 'Houston, TX 77030']}
# Fuddruckers {'address1': '2400 B S MacGregor Way', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['2400 B S MacGregor Way', 'Houston, TX 77021']}
# Taco Bell {'address1': '3720 Old Spanish Trail', 'address2': None, 'address3': None, 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['3720 Old Spanish Trail', 'Houston, TX 77021']}
# Sonic Drive-In {'address1': '13280 Almeda Rd', 'address2': None, 'address3': None, 'city': 'Houston', 'zip_code': '77045', 'country': 'US', 'state': 'TX', 'display_address': ['13280 Almeda Rd', 'Houston, TX 77045']}
# Church's Chicken {'address1': '13350 Almeda Rd', 'address2': '', 'address3': None, 'city': 'Houston', 'zip_code': '77045', 'country': 'US', 'state': 'TX', 'display_address': ['13350 Almeda Rd', 'Houston, TX 77045']}
# Jack in the Box {'address1': '4400 W Fuqua St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77045', 'country': 'US', 'state': 'TX', 'display_address': ['4400 W Fuqua St', 'Houston, TX 77045']}
# KFC {'address1': '4044 W Fuqua St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77045', 'country': 'US', 'state': 'TX', 'display_address': ['4044 W Fuqua St', 'Houston, TX 77045']}
# Poke In The Bowl {'address1': '6611 Main St', 'address2': None, 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['6611 Main St', 'Houston, TX 77030']}
# Pokeworks {'address1': '8505 Main St', 'address2': 'Ste 150', 'address3': None, 'city': 'Houston', 'zip_code': '77025', 'country': 'US', 'state': 'TX', 'display_address': ['8505 Main St', 'Ste 150', 'Houston, TX 77025']}
# Louisiana Famous Fried Chicken {'address1': '3602 Old Spanish Trl', 'address2': 'Ste C', 'address3': '', 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['3602 Old Spanish Trl', 'Ste C', 'Houston, TX 77021']}
# Taco Bell {'address1': '3155 S Loop West', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77054', 'country': 'US', 'state': 'TX', 'display_address': ['3155 S Loop West', 'Houston, TX 77054']}
# American Deli {'address1': '6102 Scott St', 'address2': None, 'address3': '', 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['6102 Scott St', 'Houston, TX 77021']}
# KFC {'address1': '9227 Cullen Blvd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77051', 'country': 'US', 'state': 'TX', 'display_address': ['9227 Cullen Blvd', 'Houston, TX 77051']}
# Miller's Cafe {'address1': '6560 Fannin St', 'address2': 'Ste 110', 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['6560 Fannin St', 'Ste 110', 'Houston, TX 77030']}
# Taco Cabana {'address1': '8101 S Main St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77025', 'country': 'US', 'state': 'TX', 'display_address': ['8101 S Main St', 'Houston, TX 77025']}
# Chick-fil-A {'address1': '6550 Bertner Ave', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['6550 Bertner Ave', 'Houston, TX 77030']}
# Maxim Seafood {'address1': '6510 Weston St', 'address2': None, 'address3': '', 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['6510 Weston St', 'Houston, TX 77021']}
# Subway {'address1': '9025 Cullen Blvd', 'address2': 'Ste 100', 'address3': '', 'city': 'Houston', 'zip_code': '77051', 'country': 'US', 'state': 'TX', 'display_address': ['9025 Cullen Blvd', 'Ste 100', 'Houston, TX 77051']}
# Chick-fil-A {'address1': '1515 Holcombe Blvd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['1515 Holcombe Blvd', 'Houston, TX 77030']}
# McDonald's {'address1': '6621 Fannin St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['6621 Fannin St', 'Houston, TX 77030']}
# Jack in the Box {'address1': '8767 S Main St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77025', 'country': 'US', 'state': 'TX', 'display_address': ['8767 S Main St', 'Houston, TX 77025']}
# Wing Quarter {'address1': '3929 Old Spanish Trl', 'address2': 'Ste 100', 'address3': None, 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['3929 Old Spanish Trl', 'Ste 100', 'Houston, TX 77021']}
# Chick-fil-A {'address1': '3801 Cullen Blvd', 'address2': None, 'address3': None, 'city': 'Houston', 'zip_code': '77004', 'country': 'US', 'state': 'TX', 'display_address': ['3801 Cullen Blvd', 'Houston, TX 77004']}
# Taco Bell {'address1': '2245 West Holcombe Blvd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['2245 West Holcombe Blvd', 'Houston, TX 77030']}
# Whataburger {'address1': '3624 Old Spanish Trl', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['3624 Old Spanish Trl', 'Houston, TX 77021']}
# Ms Betty's Kitchen {'address1': '4101 Reed Rd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77051', 'country': 'US', 'state': 'TX', 'display_address': ['4101 Reed Rd', 'Houston, TX 77051']}
# Popeyes Louisiana Kitchen {'address1': '9120 Main St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77025', 'country': 'US', 'state': 'TX', 'display_address': ['9120 Main St', 'Houston, TX 77025']}
# Local Foods {'address1': '2424 Dunstan Rd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77005', 'country': 'US', 'state': 'TX', 'display_address': ['2424 Dunstan Rd', 'Houston, TX 77005']}
# Chick-fil-A {'address1': '3101 W Holcombe Blvd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77025', 'country': 'US', 'state': 'TX', 'display_address': ['3101 W Holcombe Blvd', 'Houston, TX 77025']}
# Sonic Drive-In {'address1': '8504 Main St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77025', 'country': 'US', 'state': 'TX', 'display_address': ['8504 Main St', 'Houston, TX 77025']}
# Frenchy's Chicken {'address1': '12202 Almeda Rd', 'address2': 'Ste B', 'address3': '', 'city': 'Houston', 'zip_code': '77045', 'country': 'US', 'state': 'TX', 'display_address': ['12202 Almeda Rd', 'Ste B', 'Houston, TX 77045']}
# Frenchy's Chicken {'address1': '4646 Scott St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77004', 'country': 'US', 'state': 'TX', 'display_address': ['4646 Scott St', 'Houston, TX 77004']}
# Burger King {'address1': '9349 S Main', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77025', 'country': 'US', 'state': 'TX', 'display_address': ['9349 S Main', 'Houston, TX 77025']}
# Panda Express {'address1': '4041 S. Sam Houston Pkwy E.', 'address2': None, 'address3': None, 'city': 'Houston', 'zip_code': '77047', 'country': 'US', 'state': 'TX', 'display_address': ['4041 S. Sam Houston Pkwy E.', 'Houston, TX 77047']}
# Whataburger {'address1': '2265 W Holcombe Blvd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['2265 W Holcombe Blvd', 'Houston, TX 77030']}
# Hopdoddy Burger Bar {'address1': '5510 Morningside Dr', 'address2': 'Ste 100', 'address3': None, 'city': 'Houston', 'zip_code': '77005', 'country': 'US', 'state': 'TX', 'display_address': ['5510 Morningside Dr', 'Ste 100', 'Houston, TX 77005']}
# Los Cocos Restaurant {'address1': '3419 W Orem Dr', 'address2': None, 'address3': '', 'city': 'Houston', 'zip_code': '77045', 'country': 'US', 'state': 'TX', 'display_address': ['3419 W Orem Dr', 'Houston, TX 77045']}
# Liberty Taco {'address1': '1333 Old Spanish Trl', 'address2': 'Ste 100-A', 'address3': None, 'city': 'Houston', 'zip_code': '77054', 'country': 'US', 'state': 'TX', 'display_address': ['1333 Old Spanish Trl', 'Ste 100-A', 'Houston, TX 77054']}
# Jack in the Box {'address1': '3601 Old Spanish Trail', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['3601 Old Spanish Trail', 'Houston, TX 77021']}
# Little Matt's {'address1': '6203 Edloe St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77005', 'country': 'US', 'state': 'TX', 'display_address': ['6203 Edloe St', 'Houston, TX 77005']}
# Fajita Pete's - Bellaire {'address1': '6719 Weslayan St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77005', 'country': 'US', 'state': 'TX', 'display_address': ['6719 Weslayan St', 'Houston, TX 77005']}
# McDonald's {'address1': '7410 Cullen Blvd', 'address2': None, 'address3': None, 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['7410 Cullen Blvd', 'Houston, TX 77021']}
# Taco Cabana {'address1': '5930 Gulf Frwy', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77023', 'country': 'US', 'state': 'TX', 'display_address': ['5930 Gulf Frwy', 'Houston, TX 77023']}
# Dairy Queen {'address1': '3915 Old Spanish Trail', 'address2': '', 'address3': None, 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['3915 Old Spanish Trail', 'Houston, TX 77021']}
# Golden Chick {'address1': '7121 Cullen Blvd', 'address2': None, 'address3': None, 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['7121 Cullen Blvd', 'Houston, TX 77021']}
# Popeyes Louisiana Kitchen {'address1': '4702 Scott St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77004', 'country': 'US', 'state': 'TX', 'display_address': ['4702 Scott St', 'Houston, TX 77004']}
# The Address {'address1': '3333 Raleigh St', 'address2': '', 'address3': None, 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['3333 Raleigh St', 'Houston, TX 77021']}
# Brown Bag Deli {'address1': '2540 Amherst St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77005', 'country': 'US', 'state': 'TX', 'display_address': ['2540 Amherst St', 'Houston, TX 77005']}
# Jimmy John's {'address1': '2401 W Holcombe Blvd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['2401 W Holcombe Blvd', 'Houston, TX 77030']}
# Pizza Hut {'address1': '9441 Cullen Blvd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77033', 'country': 'US', 'state': 'TX', 'display_address': ['9441 Cullen Blvd', 'Houston, TX 77033']}
# Burger King {'address1': '2116 W Holcombe Blvd', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['2116 W Holcombe Blvd', 'Houston, TX 77030']}
# Fuddruckers {'address1': '2400 B S MacGregor Way', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['2400 B S MacGregor Way', 'Houston, TX 77021']}
# Taco Bell {'address1': '3720 Old Spanish Trail', 'address2': None, 'address3': None, 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['3720 Old Spanish Trail', 'Houston, TX 77021']}
# Sonic Drive-In {'address1': '13280 Almeda Rd', 'address2': None, 'address3': None, 'city': 'Houston', 'zip_code': '77045', 'country': 'US', 'state': 'TX', 'display_address': ['13280 Almeda Rd', 'Houston, TX 77045']}
# Church's Chicken {'address1': '13350 Almeda Rd', 'address2': '', 'address3': None, 'city': 'Houston', 'zip_code': '77045', 'country': 'US', 'state': 'TX', 'display_address': ['13350 Almeda Rd', 'Houston, TX 77045']}
# Jack in the Box {'address1': '4400 W Fuqua St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77045', 'country': 'US', 'state': 'TX', 'display_address': ['4400 W Fuqua St', 'Houston, TX 77045']}
# KFC {'address1': '4044 W Fuqua St', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77045', 'country': 'US', 'state': 'TX', 'display_address': ['4044 W Fuqua St', 'Houston, TX 77045']}
# Poke In The Bowl {'address1': '6611 Main St', 'address2': None, 'address3': '', 'city': 'Houston', 'zip_code': '77030', 'country': 'US', 'state': 'TX', 'display_address': ['6611 Main St', 'Houston, TX 77030']}
# Pokeworks {'address1': '8505 Main St', 'address2': 'Ste 150', 'address3': None, 'city': 'Houston', 'zip_code': '77025', 'country': 'US', 'state': 'TX', 'display_address': ['8505 Main St', 'Ste 150', 'Houston, TX 77025']}
# Louisiana Famous Fried Chicken {'address1': '3602 Old Spanish Trl', 'address2': 'Ste C', 'address3': '', 'city': 'Houston', 'zip_code': '77021', 'country': 'US', 'state': 'TX', 'display_address': ['3602 Old Spanish Trl', 'Ste C', 'Houston, TX 77021']}

# %%
print(restaurant_var)
# Out:
# None

# %%
# Turn into dataframe

cols = list(business_data['businesses'][0].keys())
df = pd.DataFrame(columns=cols)
for biz in business_data['businesses']:
    df = df.append(biz, ignore_index=True)
    df = df.drop(['id', 'categories','alias','image_url', 'is_closed', 'url', 'review_count', 'rating', 'transactions', 'phone', 'distance', 'display_phone', 'coordinates'],axis=1)
df.head()

# %%
# Turn into dataframe

cols = list(business_data['businesses'][0].keys())
df = pd.DataFrame(columns=cols)
for biz in business_data['businesses']:
    df = df.append(biz, ignore_index=True)
    df = df.drop(['id', 'categories','alias','image_url', 'is_closed', 'url', 'review_count', 'rating', 'transactions', 'phone', 'distance', 'display_phone', 'coordinates'],axis=1)
df.head()
# Out:
#                         name price  \
# 0                Whataburger     $
# 1       Clutch City Cluckers    $$
# 2               Jimmy John's     $
# 3                Smashburger     $
# 4  Popeyes Louisiana Kitchen     $
#
#                                             location
# 0  {'address1': '7629 W Bellfort St', 'address2':...
# 1  {'address1': '5550 Val Verde St', 'address2': ...
# 2  {'address1': '5124 Bissonnet St', 'address2': ...
# 3  {'address1': '7811 Main St', 'address2': '', '...
# 4  {'address1': '5625 Richmond Ave', 'address2': ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9540\1035781333.py in <module>
# ----> 1 results.show()
#
# AttributeError: 'list' object has no attribute 'show'
