# %%
import pandas as pd

# %%
zips_data_df = pd.read_csv("data/My_20_Zips_Results.csv", index_col="Name", dtype={"Zip Code":"string"} )

# %%
zips_data_df
# Out:
#                                                      Type  \
# Name
# ('The Marketplace Café',)                      sandwiches
# ("Hot Harry's Fresh Burritos",)                   mexican
# ("McDonald's",)                                   burgers
# ("Otto's Kitchen & Comfort",)            breakfast_brunch
# ('Burger King',)                                  burgers
# ...                                                   ...
# ("McDonald's",)                                   burgers
# ('Olive Garden Italian Restaurant',)              italian
# ('Pride',)                                servicestations
# ("McDonald's",)                                   hotdogs
# ('Storrowton Tavern & Carriage House',)      tradamerican
#
#                                                           Address    Zip Code
# Name
# ('The Marketplace Café',)                        ('53 North St',)  ('01201',)
# ("Hot Harry's Fresh Burritos",)                  ('37 North St',)  ('01201',)
# ...

# %%
zips_data_df.style.format({:.2f})
